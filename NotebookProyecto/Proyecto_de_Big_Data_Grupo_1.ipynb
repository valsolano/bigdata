# %% [markdown]
# # 1. Predicción de Vuelos Aéreos
#
#
# ##  Introducción
#
# Se redacta cuando el proyecto esté listo.
#
#
# ##  Antecedentes
#
# En el mundo del consumismo en el que vivimos, la industria aérea representa uno de los sectores más dinámicos en términos de fijación de presios ya que, a diferencia de otros productos que podemos encontrar en el mercado con precios más estables, los tiquetes de avión suelen experimentar cambios significativos en cuestión de segundos. Estas inconsistencias pueden depender de múltiples factores como la demanda, comptencia, costos operativos, y algunas más específicas para cada vuelo como la duración, si cuenta con escalas o la clase del servicio.
# En el mercado aéreo de la India, particularmente en las rutas que conectan las seis principales ciudades metropolitanas (Delhi, Mumbai, Bangalore, Kolkata, Hyderabad y Chennai), se ha experimentado un crecimiento en la demanda de viajes aéreos. Las agencias de viajes en línea operan en un entorno altamente competitivo donde deben ofrecer a sus clientes las mejores recomendaciones de compra para mantener su lealtad y confianza. Por lo tanto, el desarrollo de un modelo que pueda analizar patrones de opciones de vuelo y predecir con precisión los precios futuros se vuelve una necesidad estratégica para mejorar la experiencia del cliente y mantenerse competitivos en el mercado.
#
#
# ## Definición del problema
#
# El precio de los vuelos aéreos presenta una alta variabilidad debido a factores como la aerolínea, el origen y destino, la duración del vuelo, el número de escalas, la fecha de viaje y el momento de compra, lo que dificulta que los usuarios puedan tomar decisiones informadas al adquirir boletos aéreos. Aunque existe una gran cantidad de datos históricos disponibles, estos no siempre son aprovechados mediante técnicas de Big Data y análisis predictivo para anticipar el comportamiento de los precios. Por ello, surge la necesidad de desarrollar un modelo de predicción de precios de vuelos basado en el análisis de grandes volúmenes de datos, que permita estimar de manera más precisa el costo de los boletos y apoyar la toma de decisiones eficientes.
#
#
# ## Justificación
#
# Implementar un modelo de aprendizaje automático para predecir el comportamiento de los precios de los boletos aéreos facilitará el análisis automatizado de grandes volúmenes de datos provenientes de las estimaciones. Este enfoque permitirá comprender variables como la demanda, la temporada, la ruta y el tiempo de anticipación influyen en las tarifas, apoyando la toma de decisiones estratégicas relacionadas con la gestión de precios. Además, el uso de modelos predictivos contribuirá a detectar patrones de mercado relevantes, identificar oportunidades en rutas específicas y fortalecer las estrategias comerciales, generando ventaja competitiva y un mayor valor tanto para la empresa como para los pasajeros.
#
# ## Objetivo general
#
# Desarrollar un modelo de predicción del precio de vuelos mediante el análisis de grandes volúmenes de datos históricos, utilizando técnicas de Big Data y aprendizaje automático, con el fin de estimar de manera precisa el costo de los boletos y apoyar la toma de decisiones informadas para los usuarios.
#
# ### Objetivos específicos
#
# 1.	Analizar el conjunto de datos de precios de vuelos para identificar patrones, tendencias y variables que influyen significativamente en el costo del boleto aéreo.
# 2.	Realizar un proceso de limpieza y preprocesamiento de los datos, incluyendo el tratamiento de valores nulos, variables categóricas y posibles inconsistencias.
# 3.	Seleccionar las variables más relevantes que contribuyen a la predicción del precio de los vuelos.
# 4.	Implementar y comparar diferentes modelos de predicción utilizando técnicas de análisis de datos y aprendizaje automático.
# 5.	Evaluar el desempeño de los modelos desarrollados mediante métricas estadísticas apropiadas para determinar su nivel de precisión.
#
# ## Descripción del conjunto de datos
#
# Para este trabajo se utiliza como fuente el dataset de Kaggle “Flight Price Prediction”. Este dataset trata sobre precios de tiquetes de avión y opciones de reserva de vuelos. La información fue obtenida originalmente del sitio EaseMyTrip, que es una plataforma en línea donde las personas compran vuelos, y fue recolectada mediante web scraping utilizando la herramienta Octoparse.
#
# En el dataset, cada fila representa una opción distinta de vuelo e incluye datos como la aerolínea, el código de vuelo, la ciudad de salida y destino, la hora de salida y llegada (agrupadas en rangos), la cantidad de escalas, la duración del viaje, los días restantes entre la compra y el vuelo, la clase del tiquete (Economy o Business) y el precio, que es la variable principal que se quiere analizar y predecir.
#
# La idea de usar este dataset en el proyecto es poder estudiar qué factores influyen en el precio y luego entrenar modelos para predecir el precio según las características del vuelo.
#
# ### Características del Dataset
#
# El dataset consta de las siguientes columnas:
#
# - `airline`: almacena el nombre de la aerolínea. Es una variable categórica con 6 aerolíneas distintas.
# - `flight`: guarda información del código del vuelo. Es una variable categórica.
# - `source_city`: indica la ciudad de salida del vuelo. Es una variable categórica con 6 ciudades únicas.
# - `departure_time`: indica la hora de salida, pero está agrupada en rangos. Es una variable categórica derivada con 6 etiquetas de tiempo.
# - `stops`: representa la cantidad de escalas entre origen y destino. Es una variable categórica con 3 valores distintos.
# - `arrival_time`: indica la hora de llegada, también agrupada en rangos. Es una variable categórica derivada con 6 etiquetas de tiempo.
# - `destination_city`: indica la ciudad de destino donde aterriza el vuelo. Es una variable categórica con 6 ciudades únicas.
# - `class`: indica la clase del tiquete. Es una variable categórica con 2 valores: Business y Economy.
# - `duration`: muestra la duración total del viaje en horas. Es una variable continua.
# - `days_left`: representa los días restantes entre la fecha de compra y la fecha del vuelo (se calcula como fecha del viaje - fecha de reserva). Es una variable derivada.
# - `price`: es la **variable objetivo**, y almacena el precio del tiquete.
#
# ### Tamaño del Dataset
#
# - **Instancias:** 300,261 registros.
# - **Atributos:** 11 características (10 predictoras y 1 variable objetivo: Price).
#
# ## Objetivo propuesto
#
# - Construir modelos que predigan el precio del tiquete de avión con base en las características del vuelo disponibles en el dataset.
#
# ### Limitaciones
#
# - Solo tiene vuelos entre 6 ciudades principales de India, entonces no aplica para otros destinos.
# - Los datos son de un rango de fechas específico (11 de febrero a 31 de marzo de 2022), así que en otras temporadas los precios pueden ser diferentes.
# - La hora de salida y llegada están agrupadas por rangos y no en horas exactas, lo que reduce el detalle del análisis.
# - Al venir de web scraping de una página (EaseMyTrip), los precios pueden depender de lo que el sitio mostraba en ese momento.
#
# ### Acceso al Dataset
#
# * Disponible en [Housing Data Set](https://www.kaggle.com/datasets/shubhambathwal/flight-price-prediction).
#
# ## Referencia de la fuente:
#
# Bathwal, S. (2022). Flight Price Prediction [Conjunto de datos]. Kaggle. https://www.kaggle.com/datasets/shubhambathwal/flight-price-prediction (Consultado el 23 de enero de 2026).

# %% [markdown]
# ## Muestra del Dataset

# %%
import pandas as pd
dfVuelos = pd.read_csv("C:\\Users\\valer\\Documents\\GitHub\\bigdata\\NotebookProyecto\\flights.csv")
dfVuelos
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# ...

# %%
dfVuelos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  str
#  1   flight            300153 non-null  str
#  2   source_city       300153 non-null  str
#  3   departure_time    300153 non-null  str
#  4   stops             300153 non-null  str
#  5   arrival_time      300153 non-null  str
#  6   destination_city  300153 non-null  str
#  7   class             300153 non-null  str
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), str(8)
# memory usage: 25.2 MB

# %% [markdown]
# ## Revisión inicial del data set

# %%
import sys
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dfVuelos.describe()
# Out:
#             duration      days_left          price
# count  300153.000000  300153.000000  300153.000000
# mean       12.221021      26.004751   20889.660523
# std         7.191997      13.561004   22697.767366
# min         0.830000       1.000000    1105.000000
# 25%         6.830000      15.000000    4783.000000
# 50%        11.250000      26.000000    7425.000000
# 75%        16.170000      38.000000   42521.000000
# max        49.830000      49.000000  123071.000000

# %%
# Histogramas de las variables numéricas
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Precio
axes[0].hist(dfVuelos['price'], bins=50)
axes[0].set_xlabel('Precio')
axes[0].set_ylabel('Frecuencia')
axes[0].set_title('Distribución de Precios')

# Duración
axes[1].hist(dfVuelos['duration'], bins=50)
axes[1].set_xlabel('Duración (horas)')
axes[1].set_ylabel('Frecuencia')
axes[1].set_title('Distribución de Duración')

# Días faltantes
axes[2].hist(dfVuelos['days_left'], bins=49)
axes[2].set_xlabel('Días de Anticipación')
axes[2].set_ylabel('Frecuencia')
axes[2].set_title('Distribución de Días de Anticipación')

plt.tight_layout()
plt.show()

# %%
## Boxplot de la variable objetivo
import seaborn as sns
bp = sns.boxplot(data=dfVuelos.loc[:, ["price"]])
_ = bp.set_ylabel("price")

# %%
#Descripción de la variable objetivo
dfVuelos.price.describe()
# Out:
# count    300153.000000
# mean      20889.660523
# std       22697.767366
# min        1105.000000
# 25%        4783.000000
# 50%        7425.000000
# 75%       42521.000000
# max      123071.000000
# Name: price, dtype: float64

# %% [markdown]
# ## Comparación de distribuciones usado boxplots

# %%
# Atributos numéricos del DataSet
dfVuelosN = dfVuelos.select_dtypes(include=["number"])
dfVuelosN
# Out:
#         duration  days_left  price
# 0           2.17          1   5953
# 1           2.33          1   5953
# 2           2.17          1   5956
# 3           2.25          1   5955
# 4           2.33          1   5955
# ...          ...        ...    ...
# 300148     10.08         49  69265
# 300149     10.42         49  77105
# 300150     13.83         49  79099
# 300151     10.00         49  81585
# 300152     10.08         49  81585
#
# [300153 rows x 3 columns]

# %%
dfVuelosMelted = dfVuelosN.melt(var_name="Variable", value_name="Valor")
dfVuelosMelted
# Out:
#         Variable     Valor
# 0       duration      2.17
# 1       duration      2.33
# 2       duration      2.17
# 3       duration      2.25
# 4       duration      2.33
# ...          ...       ...
# 900454     price  69265.00
# 900455     price  77105.00
# 900456     price  79099.00
# 900457     price  81585.00
# 900458     price  81585.00
#
# [900459 rows x 2 columns]

# %% [markdown]
# ### Boxplots

# %%
# Boxplot de todas las variables numéricas
plt.figure(figsize=(10, 5))

sns.boxplot(x="Variable", y="Valor", data=dfVuelosMelted)
plt.title("Distribución de Variables")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Precio por Clase**

# %%
# Boxplot de precio por clase
dfVuelos.boxplot(column='price', by='class', figsize=(10,6))
plt.xlabel('Clase')
plt.ylabel('Precio')
plt.title('Precio por Clase')
plt.suptitle('')
plt.show()

# %% [markdown]
# **Precio por Aerolínea**

# %%
# Boxplot de precio por aerolínea
dfVuelos.boxplot(column='price', by='airline', figsize=(10,6))

plt.xticks(rotation=45)
plt.xlabel('Aerolínea')
plt.ylabel('Precio')
plt.title('Precio por Aerolínea')
plt.suptitle('')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ubicar nulos

# %%
dfVuelos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  str
#  1   flight            300153 non-null  str
#  2   source_city       300153 non-null  str
#  3   departure_time    300153 non-null  str
#  4   stops             300153 non-null  str
#  5   arrival_time      300153 non-null  str
#  6   destination_city  300153 non-null  str
#  7   class             300153 non-null  str
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), str(8)
# memory usage: 25.2 MB

# %%
# Verificar si hay filas con valores nulos
null_rows_idx = dfVuelos.isnull().any(axis=1)
print(null_rows_idx[null_rows_idx == True])
dfVuelos.loc[null_rows_idx].head()
# Out:
# Series([], dtype: bool)
# Empty DataFrame
# Columns: [airline, flight, source_city, departure_time, stops, arrival_time, destination_city, class, duration, days_left, price]
# Index: []

# %% [markdown]
# ## Preparar Training y Test Sets

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Totalmente aleatorio**

# %%
# Dividir el DataFrame en conjuntos de entrenamiento y prueba de forma aleatoria
train_set, test_set = train_test_split(dfVuelos, test_size=0.2, random_state=42)

print('Tamaño del train_set', train_set.shape)
print('Tamaño del test_set', test_set.shape)
# Out:
# Tamaño del train_set (240122, 11)
# Tamaño del test_set (60031, 11)

# %% [markdown]
# **Estratificado**

# %%
# Histograma por clase, mucho desbalance entre clases
dfVuelos["class"].value_counts().sort_index().plot.bar(rot=0, grid=True)
plt.xlabel('Clase de Vuelo')
plt.ylabel('Número de vuelos')
plt.title('Distribución de Clases de Vuelo')
plt.show()

# %%
# División aleatoria
train_set, test_set = train_test_split(dfVuelos, test_size=0.2, random_state=42)

print('Tamaño del train_set', train_set.shape)
print('Tamaño del test_set', test_set.shape)
# Out:
# Tamaño del train_set (240122, 11)
# Tamaño del test_set (60031, 11)

# %%
# División estratificada por clase
strat_train_set, strat_test_set = train_test_split(dfVuelos, 
                                                     test_size=0.2, 
                                                     stratify=dfVuelos["class"], 
                                                     random_state=42)

print('Tamaño del strat_train_set', strat_train_set.shape)
print('Tamaño del strat_test_set', strat_test_set.shape)
# Out:
# Tamaño del strat_train_set (240122, 11)
# Tamaño del strat_test_set (60031, 11)

# %%
# Comparación de division de clases
def compare_sampling(overall, stratified, random):
    compare_props = pd.DataFrame({
        'Overall %': overall * 100,
        'Stratified %': stratified * 100,
        'Random %': random * 100
    })
    compare_props['Strat. Error %'] = ((compare_props['Stratified %'] / compare_props['Overall %']) - 1) * 100
    compare_props['Rand. Error %'] = ((compare_props['Random %'] / compare_props['Overall %']) - 1) * 100
    return compare_props

compare_props_class = compare_sampling(
    dfVuelos['class'].value_counts(normalize=True).sort_index(),
    strat_train_set['class'].value_counts(normalize=True).sort_index(),
    train_set['class'].value_counts(normalize=True).sort_index()
)

compare_props_class
# Out:
#           Overall %  Stratified %   Random %  Strat. Error %  Rand. Error %
# class
# Business  31.146449     31.146251  31.139171       -0.000636      -0.023366
# Economy   68.853551     68.853749  68.860829        0.000288       0.010570

# %%
# Distribución de categorías de precio
# Crear categorías de precio (bajo/medio/alto)
dfVuelos['price_cat'] = pd.cut(dfVuelos['price'],
                                bins=[0, 10000, 30000, np.inf],
                                labels=['bajo', 'medio', 'alto'])

dfVuelos
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price price_cat
# ...

# %%
# Histograma de categorías de precio
dfVuelos['price_cat'].value_counts().plot(kind='bar', figsize=(8,4))
plt.xlabel('Categoría de Precio')
plt.ylabel('Frecuencia')
plt.title('Distribución de Categorías de Precio')
plt.xticks(rotation=0)
plt.show()

# %%
# División aleatoria
train_set, test_set = train_test_split(dfVuelos, test_size=0.2, random_state=42)

print('Tamaño del train_set', train_set.shape)
print('Tamaño del test_set', test_set.shape)
# Out:
# Tamaño del train_set (240122, 12)
# Tamaño del test_set (60031, 12)

# %%
# División estratificada por precio
strat_train_set, strat_test_set = train_test_split(dfVuelos, 
                                                     test_size=0.2, 
                                                     stratify=dfVuelos["price_cat"], 
                                                     random_state=42)

print('Tamaño del strat_train_set', strat_train_set.shape)
print('Tamaño del strat_test_set', strat_test_set.shape)
# Out:
# Tamaño del strat_train_set (240122, 12)
# Tamaño del strat_test_set (60031, 12)

# %%
# Comparación de division por categoría de precios
def compare_sampling(overall, stratified, random):
    compare_props = pd.DataFrame({
        'Overall %': overall * 100,
        'Stratified %': stratified * 100,
        'Random %': random * 100
    })
    compare_props['Strat. Error %'] = ((compare_props['Stratified %'] / compare_props['Overall %']) - 1) * 100
    compare_props['Rand. Error %'] = ((compare_props['Random %'] / compare_props['Overall %']) - 1) * 100
    return compare_props

compare_props_price = compare_sampling(
    dfVuelos['price_cat'].value_counts(normalize=True).sort_index(),
    strat_train_set['price_cat'].value_counts(normalize=True).sort_index(),
    train_set['price_cat'].value_counts(normalize=True).sort_index()
)

compare_props_price
# Out:
#            Overall %  Stratified %   Random %  Strat. Error %  Rand. Error %
# price_cat
# bajo       57.855161     57.855174  57.839348        0.000023      -0.027331
# medio      12.938735     12.938839  12.972572        0.000810       0.261522
# alto       29.206105     29.205987  29.188079       -0.000404      -0.061718
